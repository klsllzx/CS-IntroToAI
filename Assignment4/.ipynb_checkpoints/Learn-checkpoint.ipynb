# %%
import PIL
from PIL import Image

# %%
base=64
image=Image.open("dataset/sunrise/download.jpeg")

# %%
print(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=276x183 at 0x1123859E8>

# %%
display(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=276x183 at 0x1123859E8>

# %%
ls=[1,2,3]
display(ls)
# Out:
# [1, 2, 3]

# %%
img = image.resize((base,base), PIL.Image.ANTIALIAS)

# %%
display(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=276x183 at 0x1123859E8>

# %%
display(img)
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x1125BCF28>

# %%
img.save("updated/test.jpg")

# %%
import os

# %%
path=os.walk("dataset")
